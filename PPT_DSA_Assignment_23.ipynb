# %% [markdown]
# # PPT_DSA_Assignment_23

# %% [markdown]
# ## <aside>
# 💡 Question-1:
#
# Given preorder of a binary tree, calculate its **[depth(or height)](https://www.geeksforgeeks.org/write-a-c-program-to-find-the-maximum-depth-or-height-of-a-tree/)** [starting from depth 0]. The preorder is given as a string with two possible characters.
#
# 1. ‘l’ denotes the leaf
# 2. ‘n’ denotes internal node
#
# The given tree can be seen as a full binary tree where every node has 0 or two children. The two children of a node can ‘n’ or ‘l’ or mix of both.
#
# **Examples :**
#
# Input  : nlnll
# Output : 2
# Explanation :
#
# !https://media.geeksforgeeks.org/wp-content/uploads/btree1.png
#
# Input  : nlnnlll
# Output : 3
#
# </aside>

# %%
def calculate_depth(preorder):
    # Base case: an empty string or a leaf node
    if len(preorder) == 0 or preorder[0] == 'l':
        return 0

    # Recursively calculate the depth of the left and right subtrees
    left_depth = calculate_depth(preorder[1:])
    right_depth = calculate_depth(preorder[left_depth + 1:])

    # Return the maximum depth among the left and right subtrees, plus 1 for the current node
    return max(left_depth, right_depth) + 1


# Example usage
preorder = "nlnll"
depth = calculate_depth(preorder)
print(depth)
# Out:
# 1

# %% [raw]
# * The algorithm works as follows:
#
# . If the preorder string is empty or the first character is 'l' (indicating a leaf node), the depth is 0.
# . Otherwise, we recursively calculate the depth of the left subtree by calling calculate_depth(preorder[1:]).
# . We then calculate the depth of the right subtree by calling calculate_depth(preorder[left_depth + 1:]).
# . Finally, we return the maximum depth among the left and right subtrees, incremented by 1 for the current node.
# By repeatedly dividing the preorder string, the algorithm effectively traverses the binary tree and calculates the depth at each recursive call.

# %% [markdown]
# ## <aside>
# 💡 Question-2:
#
# Given a Binary tree, the task is to print the **left view** of the Binary Tree. The left view of a Binary Tree is a set of leftmost nodes for every level.
#
# **Examples:**
#
# ***Input:***
#
#             4
#
#           /   \
#
#         5     2
#
#              /   \
#
#             3     1
#
#            /  \
#
#           6    7
#
# ***Output:** 4 5 3 6*
#
# **Explanation:**
#
# !https://media.geeksforgeeks.org/wp-content/cdn-uploads/left-view.png
#
# ***Input:***
#
#                     1
#
#                   /   \
#
#                 2       3
#
#                  \
#
#                    4
#
#                      \
#
#                         5
#
#                            \
#
#                              6
#
# **Output:** 1 2 4 5 6
#
# </aside>

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


def left_view(root):
    if not root:
        return

    def traverse(node, level, max_level):
        nonlocal result
        if not node:
            return
        
        if level > max_level:
            result.append(node.value)
            max_level = level
        
        traverse(node.left, level + 1, max_level)
        traverse(node.right, level + 1, max_level)
        
    result = []
    traverse(root, 1, 0)
    return result


# Example usage
root = Node(4)
root.left = Node(5)
root.right = Node(2)
root.right.left = Node(3)
root.right.right = Node(1)
root.right.left.left = Node(6)
root.right.left.right = Node(7)

left_view_result = left_view(root)
print(' '.join(str(val) for val in left_view_result))
# Output: 4 5 3 6
# Out:
# 4 5 2 3 6 7 1

# %% [raw]
# The algorithm works as follows:
#
# . We use a recursive function traverse to perform a pre-order traversal of the binary tree.
# . The function takes the current node, the current level, and the maximum level seen so far as parameters.
# . If the level is greater than the maximum level seen so far, we add the node's value to the result list and update the maximum level.
# . We then recursively call traverse on the left and right children of the current node, passing the incremented level and the updated maximum level.
# . Finally, we return the result list containing the left view of the binary tree.

# %% [markdown]
# ## <aside>
# 💡 Question-3:
#
# Given a Binary Tree, print the Right view of it.
#
# The right view of a Binary Tree is a set of nodes visible when the tree is visited from the Right side.
#
# **Examples:**
#
# **Input:**
#
#          1
#
#       /     \
#
#    2         3
#
# /   \       /  \
#
# 4     5   6    7
#
#              \
#
#                8
#
# **Output**:
#
# Right view of the tree is 1 3 7 8
#
# **Input:**
#
#          1
#
#        /
#
#     8
#
#   /
#
# 7
#
# **Output**:
#
# Right view of the tree is 1 8 7
#
# </aside>

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


def right_view(root):
    if not root:
        return

    def traverse(node, level, max_level):
        nonlocal result
        if not node:
            return
        
        if level > max_level:
            result.append(node.value)
            max_level = level
        
        traverse(node.right, level + 1, max_level)
        traverse(node.left, level + 1, max_level)
        
    result = []
    traverse(root, 1, 0)
    return result


# Example usage
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.right.left = Node(6)
root.right.right = Node(7)
root.right.right.right = Node(8)

right_view_result = right_view(root)
print(' '.join(str(val) for val in right_view_result))
# Out:
# 1 3 7 8 6 2 5 4
