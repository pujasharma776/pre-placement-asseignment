# %% [markdown]
# # PPT_Assignment 6

# %% [markdown]
# ## <aside>
# 💡 **Question 1**
#
# A permutation perm of n + 1 integers of all the integers in the range [0, n] can be represented as a string s of length n where:
#
# - s[i] == 'I' if perm[i] < perm[i + 1], and
# - s[i] == 'D' if perm[i] > perm[i + 1].
#
# Given a string s, reconstruct the permutation perm and return it. If there are multiple valid permutations perm, return **any of them**.
#
# **Example 1:**
#
# **Input:** s = "IDID"
#
# **Output:**
#
# [0,4,1,3,2]
#
# </aside>

# %%
def diStringMatch(s):
    n = len(s)
    low, high = 0, n
    perm = []
    
    for char in s:
        if char == 'I':
            perm.append(low)
            low += 1
        else:
            perm.append(high)
            high -= 1
    
    perm.append(low)  # Add the last remaining element
    
    return perm

# %% [markdown]
# #Example usage

# %%
s = "IDID"
result = diStringMatch(s)
print(result)
# Out:
# [0, 4, 1, 3, 2]

# %% [markdown]
# ## <aside>
# 💡 **Question 2**
#
# You are given an m x n integer matrix matrix with the following two properties:
#
# - Each row is sorted in non-decreasing order.
# - The first integer of each row is greater than the last integer of the previous row.
#
# Given an integer target, return true *if* target *is in* matrix *or* false *otherwise*.
#
# You must write a solution in O(log(m * n)) time complexity.
#
# **Example 1:**
#
# ![Screenshot 2023-05-29 005303.png](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/e4b0271f-15f0-4744-826b-18500ccfcb75/Screenshot_2023-05-29_005303.png)
#
# [data:image/png;base64,...](data:image/png;base64,...)
#
# **Input:** matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]], target = 3
#
# **Output:** true
#
# </aside>

# %% [raw]
# Here's the step-by-step algorithm:
#
# 1.Initialize the variables rows and cols with the number of rows and columns in the matrix, respectively.
# 2.Initialize the left variable to 0 and the right variable to rows * cols - 1.
# 3.While left <= right, do the following:
# .Calculate the middle index as mid = (left + right) // 2.
# .Convert the middle index to row and column indices as row = mid // cols and col = mid % cols.
# .Retrieve the element at the middle index in the matrix as midElement = matrix[row][col].
# 4.If midElement is equal to the target, return True.
# 5.If midElement is less than the target, update left = mid + 1 to search in the right half of the remaining matrix.
# 6.If midElement is greater than the target, update right = mid - 1 to search in the left half of the remaining matrix.
# 7.If the target is not found after the while loop, return False.

# %%
def searchMatrix(matrix, target):
    rows = len(matrix)
    cols = len(matrix[0])

    left = 0
    right = rows * cols - 1

    while left <= right:
        mid = (left + right) // 2
        row = mid // cols
        col = mid % cols
        midElement = matrix[row][col]

        if midElement == target:
            return True
        elif midElement < target:
            left = mid + 1
        else:
            right = mid - 1

    return False

# %% [markdown]
# ## <aside>
# 💡 **Question 3**
#
# Given an array of integers arr, return *true if and only if it is a valid mountain array*.
#
# Recall that arr is a mountain array if and only if:
#
# - arr.length >= 3
# - There exists some i with 0 < i < arr.length - 1 such that:
#     - arr[0] < arr[1] < ... < arr[i - 1] < arr[i]
#     - arr[i] > arr[i + 1] > ... > arr[arr.length - 1]
#
# ![Screenshot 2023-05-29 005352.png](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/5565e778-ac57-4ced-85a2-ccb13268bdf6/Screenshot_2023-05-29_005352.png)
#
# [data:image/png;base64,...](data:image/png;base64,...)
#
# **Example 1:**
#
# **Input:** arr = [2,1]
#
# **Output:**
#
# false
#
# </aside>

# %%
def validMountainArray(arr):
    n = len(arr)
    if n < 3:
        return False

    peak = max(arr)
    if arr[0] == peak or arr[n - 1] == peak:
        return False

    i = 0
    while i < n - 1 and arr[i] < arr[i + 1]:
        i += 1

    if i == 0 or i == n - 1:
        return False

    while i < n - 1 and arr[i] > arr[i + 1]:
        i += 1

    return i == n - 1

# %% [markdown]
# provided example:

# %%
arr = [2, 1]
print(validMountainArray(arr))  # Output: False
# Out:
# False

# %% [markdown]
# ## <aside>
# 💡 **Question 4**
#
# Given a binary array nums, return *the maximum length of a contiguous subarray with an equal number of* 0 *and* 1.
#
# **Example 1:**
#
# **Input:** nums = [0,1]
#
# **Output:** 2
#
# **Explanation:**
#
# [0, 1] is the longest contiguous subarray with an equal number of 0 and 1.
#
# </aside>

# %% [raw]
#  Approach:
#   1.Initialize a variable max_len to store the maximum length of the subarray and a variable count to keep track of the count of 0s and 1s encountered so far. Set count to 0 initially.
#   2.Create a dictionary count_map to store the count of count at each index of the array. Initialize count_map with {0: -1} to handle the case when the equal count is achieved at index 0.
# 3.Traverse the binary array nums and for each index i, increment count by 1 if nums[i] is 1 and decrement count by 1 if nums[i] is 0.
# 4.Check if count is already present in count_map. If it is, calculate the length of the subarray as i - count_map[count] and update max_len if necessary. If count is not present in count_map, add it to count_map with the current index i.
# 5.After traversing the entire array, return max_len as the maximum length of the contiguous subarray with an equal number of 0s and 1s.

# %%
def findMaxLength(nums):
    max_len = 0
    count = 0
    count_map = {0: -1}

    for i in range(len(nums)):
        if nums[i] == 1:
            count += 1
        else:
            count -= 1

        if count in count_map:
            subarray_len = i - count_map[count]
            max_len = max(max_len, subarray_len)
        else:
            count_map[count] = i

    return max_len

# %% [markdown]
# provided example:

# %%
 nums = [0, 1]
 print(findMaxLength(nums))
# Out:
# 2

# %% [markdown]
# ## <aside>
# 💡 **Question 5**
#
# The **product sum** of two equal-length arrays a and b is equal to the sum of a[i] * b[i] for all 0 <= i < a.length (**0-indexed**).
#
# - For example, if a = [1,2,3,4] and b = [5,2,3,1], the **product sum** would be 1*5 + 2*2 + 3*3 + 4*1 = 22.
#
# Given two arrays nums1 and nums2 of length n, return *the **minimum product sum** if you are allowed to **rearrange** the **order** of the elements in* nums1.
#
# **Example 1:**
#
# **Input:** nums1 = [5,3,4,2], nums2 = [4,2,2,5]
#
# **Output:** 40
#
# **Explanation:**
#
# We can rearrange nums1 to become [3,5,4,2]. The product sum of [3,5,4,2] and [4,2,2,5] is 3*4 + 5*2 + 4*2 + 2*5 = 40.
#
# </aside>

# %% [raw]
# 1.Sort both nums1 and nums2 in ascending order.
# 2.Initialize a variable min_product_sum to store the minimum product sum. Set it to 0 initially.
# 3.Iterate over the sorted arrays and multiply the smallest element from nums1 with the largest element from nums2. Add the result to min_product_sum.
# 4.Continue this process, multiplying the next smallest element from nums1 with the next largest element from nums2 and adding it to min_product_sum.
# 5.Finally, return min_product_sum as the minimum product sum.

# %%
def minProductSum(nums1, nums2):
    nums1.sort()
    nums2.sort(reverse=True)

    min_product_sum = 0
    for i in range(len(nums1)):
        min_product_sum += nums1[i] * nums2[i]

    return min_product_sum

# %% [markdown]
# provided example:

# %%
nums1 = [5, 3, 4, 2]
nums2 = [4, 2, 2, 5]
print(minProductSum(nums1, nums2))  # Output: 40
# Out:
# 40

# %% [markdown]
# ## <aside>
# 💡 **Question 6**
#
# An integer array original is transformed into a **doubled** array changed by appending **twice the value** of every element in original, and then randomly **shuffling** the resulting array.
#
# Given an array changed, return original *if* changed *is a **doubled** array. If* changed *is not a **doubled** array, return an empty array. The elements in* original *may be returned in **any** order*.
#
# **Example 1:**
#
# **Input:** changed = [1,3,4,2,6,8]
#
# **Output:** [1,3,4]
#
# **Explanation:** One possible original array could be [1,3,4]:
#
# - Twice the value of 1 is 1 * 2 = 2.
# - Twice the value of 3 is 3 * 2 = 6.
# - Twice the value of 4 is 4 * 2 = 8.
#
# Other original arrays could be [4,3,1] or [3,1,4].
#
# </aside>

# %% [raw]
# 1.Sort the changed array in ascending order.
# 2.Create an empty list original.
# 3.Iterate over each element num in the sorted changed array.
# 4.Check if num/2 is present in the original list. If it is, remove num/2 from the original list and continue to the next iteration.
# 5.If num/2 is not present in the original list, return an empty list since changed is not a doubled array.
# 6.If the loop completes without returning, append num/2 to the original list.
# 7.Return the original list.

# %%
def findOriginalArray(changed):
    changed.sort()
    original = []

    for num in changed:
        if num / 2 in original:
            original.remove(num / 2)
        else:
            return []

        original.append(num)

    return original

# %% [markdown]
# provided example:

# %%
changed = [1, 3, 4, 2, 6, 8]
print(findOriginalArray(changed))  # Output: [1, 3, 4]
# Out:
# []
