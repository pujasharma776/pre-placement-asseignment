# %% [markdown]
# # PPT_Assignment_21 DSA

# %% [markdown]
# ## <aside>
# 💡 Question-1
#
# You are given a binary tree. The binary tree is represented using the TreeNode class. Each TreeNode has an integer value and left and right children, represented using the TreeNode class itself. Convert this binary tree into a binary search tree.
#
# Input:
#
#         10
#
#        /   \
#
#      2      7
#
#    /   \
#
#  8      4
#
# Output:
#
#         8
#
#       /   \
#
#     4     10
#
#   /   \
#
# 2      7
#
# </aside>

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None


def binary_tree_to_bst(root):
    # Perform in-order traversal to get sorted values
    def inorder_traversal(node):
        if node is None:
            return []
        return inorder_traversal(node.left) + [node.val] + inorder_traversal(node.right)

    def build_bst(values):
        if not values:
            return None

        # Find middle element as the root
        mid = len(values) // 2
        root = TreeNode(values[mid])

        # Recursively build left and right subtrees
        root.left = build_bst(values[:mid])
        root.right = build_bst(values[mid + 1:])

        return root

    # Get sorted values from in-order traversal
    values = inorder_traversal(root)

    # Build binary search tree using sorted values
    bst_root = build_bst(values)

    return bst_root


# Create the binary tree
root = TreeNode(10)
root.left = TreeNode(2)
root.right = TreeNode(7)
root.left.left = TreeNode(8)
root.left.right = TreeNode(4)

# Convert binary tree to binary search tree
bst_root = binary_tree_to_bst(root)

# Function to print in-order traversal of a binary tree
def print_inorder(node):
    if node is None:
        return
    print_inorder(node.left)
    print(node.val, end=" ")
    print_inorder(node.right)

# Print the in-order traversal of the resulting binary search tree
print_inorder(bst_root)
# Out:
# 8 2 4 10 7

# %% [markdown]
# ## <aside>
# 💡 Question-3:
#
# Write a program to convert a binary tree to a doubly linked list.
#
# Input:
#
#         10
#
#        /   \
#
#      5     20
#
#            /   \
#
#         30     35
#
# Output:
#
# 5 10 30 20 35
#
# </aside>

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None


def binary_tree_to_doubly_linked_list(root):
    def convert_to_doubly_linked_list(node):
        nonlocal prev

        if node is None:
            return

        convert_to_doubly_linked_list(node.left)

        node.left = prev
        if prev:
            prev.right = node

        prev = node

        convert_to_doubly_linked_list(node.right)

    prev = None
    convert_to_doubly_linked_list(root)

    # Traverse the doubly linked list
    while root and root.left:
        root = root.left

    # Print the values of the doubly linked list
    while root:
        print(root.val, end=" ")
        root = root.right


# Create the binary tree
root = TreeNode(10)
root.left = TreeNode(5)
root.right = TreeNode(20)
root.right.left = TreeNode(30)
root.right.right = TreeNode(35)

# Convert binary tree to doubly linked list and print the values
binary_tree_to_doubly_linked_list(root)
# Out:
# 5 10 30 20 35

# %% [raw]
# 💡 Question-4:
#
# Write a program to connect nodes at the same level.
#
# Input:
#
#         1
#
#       /   \
#
#     2      3
#
#   /   \   /   \
#
# 4     5 6    7
#
# Output:
#
# 1 → -1
#
# 2 → 3
#
# 3 → -1
#
# 4 → 5
#
# 5 → 6
#
# 6 → 7
#
# 7 → -1

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None
        self.nextRight = None


def connect_nodes_at_same_level(root):
    if root is None:
        return

    # Initialize a queue
    queue = []

    # Enqueue the root node and a marker node
    queue.append(root)
    queue.append(None)

    while queue:
        # Dequeue a node from the front of the queue
        node = queue.pop(0)

        # Check if the dequeued node is a marker node
        if node is None:
            # If the queue is not empty, enqueue the marker node back into the queue
            if queue:
                queue.append(None)
        else:
            # Set the nextRight pointer of the dequeued node
            node.nextRight = queue[0] if queue[0] is not None else None

            # Enqueue the left child if it exists
            if node.left:
                queue.append(node.left)

            # Enqueue the right child if it exists
            if node.right:
                queue.append(node.right)

    # Function to print the connections at each level
    def print_connections(node):
        while node:
            print(node.val, end=" → ")
            node = node.nextRight
        print("-1")

    # Traverse the modified tree to print the connections at each level
    print_connections(root.left)
    print_connections(root.right)


# Create the binary tree
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

# Connect nodes at the same level and print the connections
connect_nodes_at_same_level(root)
# Out:
# 2 → 3 → -1
# 3 → -1
